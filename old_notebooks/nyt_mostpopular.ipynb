# %%
import pandas as pd
import requests
import numpy as np

# %%
from pymongo import MongoClient
client = MongoClient()
# Initiate Database
db = client['nyt_emailed_9_8_15']
# Initiate Table
tab = db['table']

# %%
def single_query(link, payload):
    response = requests.get(link, params=payload)
    if response.status_code != 200:
         print 'WARNING', response.status_code
    else:
         return response.json()
# if __name__ == '__main__':
#     link = 'http://api.nytimes.com/svc/community/v3/comments/by-date'
#     payload = {'api-key': '60a3f7d54baade3ed03a40bdb5f5e866:3:50984754', 'date': '2015-08-25'}
#     html_str = single_query(link, payload)

# %% [markdown]
# ### MOST EMAILED

# %%
link = "http://api.nytimes.com/svc/mostpopular/v2/mostemailed/all-sections/1.json"
payload = {'api-key': 'c16ac6228a7e024ea9c9d7a423f4ffbf:9:50984754'}
content = single_query(link, payload)
content
# Out:
# {u'copyright': u'Copyright (c) 2015 The New York Times Company.  All Rights Reserved.',
#  u'num_results': 976,
#  u'results': [{u'abstract': u'According to legend, the humble dwellings are ideal launchpads for remarkable lives, but lately they\u2019ve become homes to aspire to.',
#    u'byline': u'By WALTER KIRN',
#    u'column': u'',
#    u'count_type': u'EMAILED',
#    u'des_facet': [u'REAL ESTATE AND HOUSING (RESIDENTIAL)'],
#    u'geo_facet': u'',
#    u'media': [{u'caption': u'A wooden home made from 60 locally sourced trees, featured in "Hide and Seek," one of a slew of recent photo books devoted to chic cabins.',
#      u'copyright': u'Adolf Bereuter, Bernardo Bader Architects, from "Hide and Seek," Gestalten Publishers, 2014',
#      u'media-metadata': [{u'format': u'Standard Thumbnail',
#        u'height': 75,
#        u'url': u'http://static01.nyt.com/images/2015/09/27/t-magazine/27tmag-10look_sign-t_CA0/27tmag-10look_sign-t_CA0-thumbStandard.jpg',
#        u'width': 75},
# ...

# %%
num_pages = list(np.arange(0, 980, 20))
print [y for y in num_pages]
# Out:
# [0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720, 740, 760, 780, 800, 820, 840, 860, 880, 900, 920, 940, 960]

# %%
for i in num_pages:
    print i
    link = "http://api.nytimes.com/svc/mostpopular/v2/mostemailed/all-sections/1.json"
    payload = {'api-key': 'c16ac6228a7e024ea9c9d7a423f4ffbf:9:50984754', 'offset': i }
    html_str = single_query(link, payload)
    for y in range(20): 
        db.tab.insert(html_str['results'][y])
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-a40c02f4a9f9> in <module>()
#       5     html_str = single_query(link, payload)
#       6     for y in range(20):
# ----> 7         db.tab.insert(html_str['results'][y])
#
# IndexError: list index out of range

# %% [markdown]
# ###MOST SHARED

# %%
# from pymongo import MongoClient
# client = MongoClient()
# Initiate Database
db = client['nyt_shared_9_8_15']
# Initiate Table
shared = db['table']

# %%
link = "http://api.nytimes.com/svc/mostpopular/v2/mostshared/all-sections/1.json"
payload = {'api-key': 'c16ac6228a7e024ea9c9d7a423f4ffbf:9:50984754'}
single_query(link, payload)
# Out:
# {u'copyright': u'Copyright (c) 2015 The New York Times Company.  All Rights Reserved.',
#  u'num_results': 859,
#  u'results': [{u'abstract': u'President Obama praised an Irving high school freshman\u2019s interest in science after his arrest raised questions of bias toward a Muslim student who happens to love tinkering.',
#    u'asset_id': 100000003914989,
#    u'byline': u'By PETER BAKER and CHRISTINE HAUSER',
#    u'column': u'',
#    u'des_facet': [u'SCHOOL DISCIPLINE (STUDENTS)', u'EDUCATION (K-12)'],
#    u'geo_facet': u'',
#    u'media': [{u'caption': u'Irving MacArthur High School student Ahmed Mohamed, 14, poses for a photo at his home in Irving, Texas on Tuesday, Sept.\xa0 15, 2015.',
#      u'copyright': u'Vernon Bryant/The Dallas Morning News, via Associated Press',
#      u'media-metadata': [{u'format': u'Standard Thumbnail',
#        u'height': 75,
#        u'url': u'http://static01.nyt.com/images/2015/09/16/us/17CLOCK2/17CLOCK2-thumbStandard.jpg',
# ...

# %%
num_pages = list(np.arange(0, 900, 20))
print [y for y in num_pages]
# Out:
# [0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720, 740, 760, 780, 800, 820, 840, 860, 880]

# %%
for i in num_pages:
    print i
    link = "http://api.nytimes.com/svc/mostpopular/v2/mostshared/all-sections/1.json"
    payload = {'api-key': 'c16ac6228a7e024ea9c9d7a423f4ffbf:9:50984754', 'offset': i }
    html_str = single_query(link, payload)
    for y in range(20): 
        db.shared.insert(html_str['results'][y])
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-ceb121e59912> in <module>()
#       5     html_str = single_query(link, payload)
#       6     for y in range(20):
# ----> 7         db.shared.insert(html_str['results'][y])
#
# IndexError: list index out of range

# %% [markdown]
# ###MOST VIEWED

# %%
db = client['nyt_viewed_9_8_15']
# Initiate Table
viewed = db['table']

# %%
link = "http://api.nytimes.com/svc/mostpopular/v2/mostviewed/all-sections/1.json"
payload = {'api-key': 'c16ac6228a7e024ea9c9d7a423f4ffbf:9:50984754'}
single_query(link, payload) #880
# Out:
# {u'copyright': u'Copyright (c) 2015 The New York Times Company.  All Rights Reserved.',
#  u'num_results': 900,
#  u'results': [{u'abstract': u'Mr. Rannazzisi, who has a Comedy Central special on Saturday, has often attributed his success to decisions made after surviving the terrorist attacks.',
#    u'adx_keywords': u'September 11 (2001);Rannazzisi, Steve (1978- );Television;Comedy Central;Buffalo Wild Wings;The League (TV Program);FXX (TV Network);Ethics (Personal)',
#    u'asset_id': 100000003913657,
#    u'byline': u'By SERGE F. KOVALESKI',
#    u'column': u'',
#    u'des_facet': [u'SEPTEMBER 11 (2001)', u'TELEVISION', u'ETHICS (PERSONAL)'],
#    u'geo_facet': u'',
#    u'id': 100000003913657,
#    u'media': [{u'caption': u'Steve Rannazzisi, during a panel for the\xa0\u201cThe League\u201d in August, apologized on Tuesday for fabricating a story about escaping from the south tower of the World Trade Center on Sept. 11, 2001.',
# ...

# %%
num_pages = list(np.arange(0, 880, 20))
print [y for y in num_pages]
# Out:
# [0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720, 740, 760, 780, 800, 820, 840, 860]

# %%
for i in num_pages:
    print i
    link = "http://api.nytimes.com/svc/mostpopular/v2/mostviewed/all-sections/1.json"
    payload = {'api-key': 'c16ac6228a7e024ea9c9d7a423f4ffbf:9:50984754', 'offset': i }
    html_str = single_query(link, payload)
    for y in range(20): 
        db.viewed.insert(html_str['results'][y])
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860

# %% [markdown]
# ###TOP STORIES API

# %%
db = client['nyt_headlines']
# Initiate Table
headlines = db['table']

# %% [markdown]
# ###PICKED 'HOME' SECTION, started 9/8/2015

# %%
#link = "http://api.nytimes.com/svc/mostpopular/v2/mostviewed/all-sections/1.json"
link = 'http://api.nytimes.com/svc/topstories/v1/home.json?'
payload = {'api-key': '7a99379950c3c6f0c56cf57f10485e85:10:50984754'}
content = single_query(link, payload)

# %%
content
# Out:
# {u'copyright': u'Copyright (c) 2015 The New York Times Company. All Rights Reserved.',
#  u'last_updated': u'2015-09-16T20:30:02-05:00',
#  u'num_results': 19,
#  u'results': [{u'abstract': u'The deal would be in the form of a deferred-prosecution agreement, and include a penalty just under $1 billion.',
#    u'byline': u'By BEN PROTESS',
#    u'created_date': u'2015-09-16T19:27:54-5:00',
#    u'des_facet': [u'Suits and Litigation (Civil)',
#     u'Automobile Safety Features and Defects'],
#    u'geo_facet': u'',
#    u'item_type': u'Article',
#    u'kicker': u'',
#    u'material_type_facet': u'News',
#    u'multimedia': u'',
#    u'org_facet': [u'General Motors'],
#    u'per_facet': u'',
#    u'published_date': u'2015-09-17T00:00:00-5:00',
#    u'section': u'Business Day',
#    u'subsection': u'',
#    u'title': u'U.S. Said to Have Settled With G.M. Over Deadly Defect',
#    u'updated_date': u'2015-09-16T19:27:53-5:00',
# ...

# %%
link = 'http://api.nytimes.com/svc/topstories/v1/home.json?'
payload = {'api-key': '7a99379950c3c6f0c56cf57f10485e85:10:50984754'}
html_str = single_query(link, payload)
for y in range(19): 
    db.headlines.insert(html_str['results'][y])
